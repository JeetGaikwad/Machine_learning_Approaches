# %%
import pandas as pd

# %%
df = pd.read_csv('2022_2023_NewYork_Sales_Cancel.csv', encoding='unicode_escape')
df.head(10)
# Out:
#    item_id item_code           ShortName  years  months     saleamt  saleqty  \
# 0        1        11       Hot Mix 12oz.   2022       1  21227.2526   7080.0
# 1        2        12      Hot Mix 1.56oz   2022       1      0.0000      0.0
# 2        3        19      Proteebeen 8oz   2022       1      0.0000      0.0
# 3        4        20      Proteebeen 8oz   2022       1      0.0000      0.0
# 4        5        25     Bhel Mix 12 oz.   2022       1   2726.5795    996.0
# 5        6        31   Chutney Mix 10oz.   2022       1      0.0000      0.0
# 6        7        32  Garlic Chutney 8oz   2022       1      0.0000      0.0
# 7        8        33  Pani-Puri Mas. 8oz   2022       1      0.0000      0.0
# 8        9        34    Tm date chny10oz   2022       1  10201.6878   5676.0
# 9       10        36      TamDat Sce18oz   2022       1   8898.9370   2580.0
#
#    cancelamt  cancelqty
# 0     541.71      180.0
# 1       0.00        0.0
# 2       0.00        0.0
# ...

# %%
df.shape
# Out:
# (109190, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109190 entries, 0 to 109189
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   item_id    109190 non-null  int64
#  1   item_code  109190 non-null  object
#  2   ShortName  109190 non-null  object
#  3   years      109190 non-null  int64
#  4   months     109190 non-null  int64
#  5   saleamt    109190 non-null  float64
#  6   saleqty    109190 non-null  float64
#  7   cancelamt  109190 non-null  float64
#  8   cancelqty  109190 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 7.5+ MB

# %%
df.isnull().sum()
# Out:
# item_id      0
# item_code    0
# ShortName    0
# years        0
# months       0
# saleamt      0
# saleqty      0
# cancelamt    0
# cancelqty    0
# dtype: int64

# %%
df.describe()
# Out:
#              item_id          years         months       saleamt  \
# count  109190.000000  109190.000000  109190.000000  1.091900e+05
# mean     3352.798809    2022.501484       6.509644  1.835542e+03
# std      2013.698831       0.500000       3.452894  1.096810e+04
# min         1.000000    2022.000000       1.000000  0.000000e+00
# 25%      1526.000000    2022.000000       4.000000  0.000000e+00
# 50%      3299.000000    2023.000000       7.000000  0.000000e+00
# 75%      5068.000000    2023.000000      10.000000  7.017054e+02
# max      7603.000000    2023.000000      12.000000  1.359762e+06
#
#             saleqty      cancelamt      cancelqty
# count  1.091900e+05  109190.000000  109190.000000
# mean   8.033935e+02     423.607534     144.758577
# std    6.355941e+03    3434.218131    1048.553341
# min    0.000000e+00     -22.880000     -12.000000
# 25%    0.000000e+00       0.000000       0.000000
# 50%    0.000000e+00       0.000000       0.000000
# ...

# %%
df.head()
# Out:
#    item_id item_code        ShortName  years  months     saleamt  saleqty  \
# 0        1        11    Hot Mix 12oz.   2022       1  21227.2526   7080.0
# 1        2        12   Hot Mix 1.56oz   2022       1      0.0000      0.0
# 2        3        19   Proteebeen 8oz   2022       1      0.0000      0.0
# 3        4        20   Proteebeen 8oz   2022       1      0.0000      0.0
# 4        5        25  Bhel Mix 12 oz.   2022       1   2726.5795    996.0
#
#    cancelamt  cancelqty
# 0     541.71      180.0
# 1       0.00        0.0
# 2       0.00        0.0
# 3       0.00        0.0
# 4       0.00        0.0

# %%
# Checking the unique values in the dataset
df['saleqty'].nunique()
# Out:
# 3861

# %%
df.head(50)
# Out:
#     item_id item_code           ShortName  years  months     saleamt  saleqty  \
# 0         1        11       Hot Mix 12oz.   2022       1  21227.2526   7080.0
# 1         2        12      Hot Mix 1.56oz   2022       1      0.0000      0.0
# 2         3        19      Proteebeen 8oz   2022       1      0.0000      0.0
# 3         4        20      Proteebeen 8oz   2022       1      0.0000      0.0
# 4         5        25     Bhel Mix 12 oz.   2022       1   2726.5795    996.0
# 5         6        31   Chutney Mix 10oz.   2022       1      0.0000      0.0
# 6         7        32  Garlic Chutney 8oz   2022       1      0.0000      0.0
# 7         8        33  Pani-Puri Mas. 8oz   2022       1      0.0000      0.0
# 8         9        34    Tm date chny10oz   2022       1  10201.6878   5676.0
# 9        10        36      TamDat Sce18oz   2022       1   8898.9370   2580.0
# 10     5412        37  KadhiChutneyMix7oz   2022       1      0.0000      0.0
# ...

# %%
index = df[(df['saleamt'] == 0) & (df['saleqty'] == 0) ].index
df.drop(index, inplace=True)

# %%
df
# Out:
#         item_id item_code           ShortName  years  months     saleamt  \
# 0             1        11       Hot Mix 12oz.   2022       1  21227.2526
# 4             5        25     Bhel Mix 12 oz.   2022       1   2726.5795
# 8             9        34    Tm date chny10oz   2022       1  10201.6878
# 9            10        36      TamDat Sce18oz   2022       1   8898.9370
# 11           11        41      Boondi 14.1oz.   2022       1   2406.6878
# ...         ...       ...                 ...    ...     ...         ...
# 109164     6025      XM17  XM SabudanaKhichdi   2023      12     67.9400
# 109166     6150      XM19  XM Dal Dhokli3.2Oz   2023      12     33.6500
# 109170     5106      ZD12    Chick Peas 29oz.   2023      12    314.2000
# 109174     5110      ZD16   KraftCheddarChs 7   2023      12    126.1600
# 109179     5977      ZD22  Pitted Dates 24 oz   2023      12    356.0800
#
#         saleqty  cancelamt  cancelqty
# 0        7080.0     541.71      180.0
# ...

# %%
data1 = df[['saleamt','saleqty','ShortName']].groupby('ShortName', as_index=False).mean().sort_values('saleamt', ascending=False)[:50]
data1
# Out:
#                ShortName        saleamt       saleqty
# 293     Chakki Atta 20Lb  340319.805988  26271.423077
# 292   Chakki Atta 20+2Lb  237656.491667  18301.666667
# 1796  Tandoori Naan 16PC  225013.968025  43242.666667
# 885    Jumbo Samosa 15pc  176788.452025  23837.333333
# 714       Gold Atta 20lb  119952.422141   8905.294118
# 127   Atta Multigrain20L  117047.259545   5250.090909
# 634   FmlyPk 20pcParatha  112224.813307  19226.769231
# 494     Dahi Whlemlk 5lb  109435.005327  24685.500000
# 1798  Tandoori Naan 5 pc   95977.055921  51555.000000
# 941   Kesar MangoPulp 30   85376.484017  39194.608696
# 383   CktlPotatoSmsa50pc   83474.633977  33907.291667
# 591   F.P.GarlicNaan12Pc   77587.508794  15046.333333
# 884     Jumbo Punjbi 8pc   62578.273522  14862.666667
# 680     Garlic Naan 4 pc   56386.785540  28030.000000
# 25     25Fmly.Pk.Paratha   55051.396543   8995.000000
# 1979   WaghBakri Tea 2LB   54149.865036   7817.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
data1.plot(kind='bar', x='ShortName', y=['saleamt','saleqty'], title="Total Sales Amount for top 10 products",figsize=(15, 7))
plt.xlabel('product')
plt.ylabel('Total Sales Amount and Quantity')
plt.show()

# %%
data2 = df[['saleamt','saleqty','years']].groupby('years', as_index=False).sum()
data2
# Out:
#    years       saleamt     saleqty
# 0   2022  1.012783e+08  46828042.0
# 1   2023  9.914453e+07  40894496.5

# %%
data2.plot(kind='bar', x='years', y=['saleamt','saleqty'], title="Total Sales in Amount and Quantity 2022-2023",figsize=(10, 5), colormap="Wistia")
plt.xlabel('Year')
plt.ylabel('Total Sales Amount and Quantity')
plt.show()

# %%
data3 = df[['saleamt','saleqty','months']].groupby('months', as_index=False).mean()
data3
# Out:
#     months      saleamt      saleqty
# 0        1  5549.056928  2337.242908
# 1        2  5074.878919  2205.086848
# 2        3  6116.370384  3188.582214
# 3        4  5485.322417  2352.860417
# 4        5  4947.848344  2301.525790
# 5        6  5503.814921  2396.615947
# 6        7  5861.977521  2382.594217
# 7        8  6083.048860  2509.647637
# 8        9  6080.782713  2594.409991
# 9       10  6123.547798  2609.996083
# 10      11  3458.084255  1522.123555
# 11      12  4731.595324  2072.530433

# %%
data3.plot(kind='bar', x='months', y=['saleamt','saleqty'], title="Total Sales in Amount and Quantity every month",figsize=(10, 5), colormap="Wistia")
plt.xlabel('Months')
plt.ylabel('Total Sales Amount and Quantity')
plt.show()

# %%
df.head(10)
# Out:
#     item_id item_code           ShortName  years  months     saleamt  saleqty  \
# 0         1        11       Hot Mix 12oz.   2022       1  21227.2526   7080.0
# 4         5        25     Bhel Mix 12 oz.   2022       1   2726.5795    996.0
# 8         9        34    Tm date chny10oz   2022       1  10201.6878   5676.0
# 9        10        36      TamDat Sce18oz   2022       1   8898.9370   2580.0
# 11       11        41      Boondi 14.1oz.   2022       1   2406.6878    876.0
# 12       12        42   Hot Chips 14.1oz.   2022       1   2188.9278    552.0
# 14       14        46  Peanuts Spicy  8oz   2022       1   4736.7090   2720.0
# 15       15        47  Cashews-Red    8oz   2022       1  12028.8810   2200.0
# 17       17        50   HotMix-X hot 12oz   2022       1  11396.0685   3800.0
# 20       20        57     Ganthiya 14.1oz   2022       1   3662.7201   1332.0
#
#     cancelamt  cancelqty
# 0      541.71      180.0
# 4        0.00        0.0
# 8    21878.17    12180.0
# ...

# %%
data4 = df[['saleamt','cancelamt','months']].groupby('months', as_index=False).mean()
data4
# Out:
#     months      saleamt    cancelamt
# 0        1  5549.056928  1106.047913
# 1        2  5074.878919  1104.799967
# 2        3  6116.370384  1104.324426
# 3        4  5485.322417   874.062966
# 4        5  4947.848344   859.705687
# 5        6  5503.814921   703.439241
# 6        7  5861.977521   691.247286
# 7        8  6083.048860   729.438538
# 8        9  6080.782713   826.623286
# 9       10  6123.547798   846.385042
# 10      11  3458.084255   362.389108
# 11      12  4731.595324   333.661400

# %%
data4.plot(x='months', y=['saleamt', 'cancelamt'], title="Comparison of sales and the cancelation monthly", colormap='viridis')
plt.xlabel('Months')
plt.ylabel('Sales and Cancelation (Amount)')
plt.show()

# %%
data5 = df[['saleqty','cancelqty','months']].groupby('months', as_index=False).mean()
data5
# Out:
#     months      saleqty   cancelqty
# 0        1  2337.242908  384.773394
# 1        2  2205.086848  408.597144
# 2        3  3188.582214  411.945627
# 3        4  2352.860417  305.954968
# 4        5  2301.525790  291.890393
# 5        6  2396.615947  284.488247
# 6        7  2382.594217  236.139498
# 7        8  2509.647637  252.489692
# 8        9  2594.409991  301.668552
# 9       10  2609.996083  243.332654
# 10      11  1522.123555  112.838454
# 11      12  2072.530433  113.380881

# %%
data5.plot(x='months', y=['saleqty', 'cancelqty'], title='Comparison of sales and the cancelation monthly', colormap='copper')
plt.xlabel('Months')
plt.ylabel('Sales and Cancelation (Quantity)')
plt.show()

# %%
data6 = df[(df['years'] == 2022) & (df['months'] <= 12)][:80].reset_index()
data6[['saleamt','saleqty','ShortName','years','months']].groupby('ShortName', as_index=False).sum()
# Out:
#              ShortName     saleamt  saleqty  years  months
# 0      All in One 12oz   2494.0464   1485.0   2022       1
# 1   Bajri Khakhra 7oz.   8504.7052   6848.0   2022       1
# 2   BajriMethiPuri12Oz   2747.3332   1125.0   2022       1
# 3   BajridhebraKhakhr6   2379.8244   1920.0   2022       1
# 4      Bhel Mix 12 oz.   2726.5795    996.0   2022       1
# ..                 ...         ...      ...    ...     ...
# 75      TamDat Sce18oz   8898.9370   2580.0   2022       1
# 76  Tamr.Concentrate 7   2136.0300   2208.0   2022       1
# 77  Tamr.Concentrate14   2665.8400   1380.0   2022       1
# 78   Tandoori Naan 10p   3967.8300   1584.0   2022       1
# 79    Tm date chny10oz  10201.6878   5676.0   2022       1
#
# [80 rows x 5 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2022 Sales')
sns.barplot(x='ShortName', y='saleamt',data=data6[:20], color="b",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data6[:20], color="lightblue", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
# prompt: give me data of item_id and its assigned short name

df[['item_id','ShortName']].groupby('item_id', as_index=False).max()
# Out:
#       item_id          ShortName
# 0           1      Hot Mix 12oz.
# 1           5    Bhel Mix 12 oz.
# 2           9   Tm date chny10oz
# 3          10     TamDat Sce18oz
# 4          11     Boondi 14.1oz.
# ...       ...                ...
# 2053     7408   Palak Sticks 7Oz
# 2054     7431        Almonds 3Lb
# 2055     7442  Black Raisins14oz
# 2056     7507  Butter Sauce 4Lbs
# 2057     7570   Mint Organic 1Lb
#
# [2058 rows x 2 columns]

# %%
data7 = df[(df['years'] == 2023) & (df['months'] <= 12)][:80].reset_index()
data7[['saleamt','saleqty','ShortName','years','months']].groupby('ShortName', as_index=False).sum()
# Out:
#              ShortName     saleamt  saleqty  years  months
# 0      All in One 12oz   2917.1100   1395.0   2023       1
# 1   BajMethiGarBhak7Oz   4651.8696   3328.0   2023       1
# 2   Bajri Khakhra 7oz.   7971.7668   5728.0   2023       1
# 3   BajridhebraKhakhr6   6337.6938   4608.0   2023       1
# 4      Bhel Mix 12 oz.   2572.3498    936.0   2023       1
# ..                 ...         ...      ...    ...     ...
# 73    Soya Sticks 10oz   3570.3948   1140.0   2023       1
# 74      TamDat Sce18oz  39311.3538  11460.0   2023       1
# 75  Tamr.Concentrate 7    599.7100    540.0   2023       1
# 76  Tamr.Concentrate14    328.4200    150.0   2023       1
# 77   Tandoori Naan 10p   3530.1600   1260.0   2023       1
#
# [78 rows x 5 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2023 Sales')
sns.barplot(x='ShortName', y='saleamt',data=data7[:20], color="b",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data7[:20], color="lightblue", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
data8 = df[['months','years','ShortName','saleqty','saleamt']][(df['months'] >=3) & (df['months'] <=5) & (df['years'] == 2022)].groupby(['ShortName','years','months'], as_index=False).sum().sort_values('saleamt',ascending=False)
data8
# Out:
#                ShortName  years  months  saleqty      saleamt
# 613     Chakki Atta 20Lb   2022       5  31925.0  290251.5300
# 1612      Gold Atta 20lb   2022       5  24033.0  271888.8500
# 611     Chakki Atta 20Lb   2022       3  31650.0  265447.1700
# 1610      Gold Atta 20lb   2022       3  19562.0  238707.7000
# 4007  Tandoori Naan 16PC   2022       3  42072.0  226929.6754
# ...                  ...    ...     ...      ...          ...
# 4419       Wet Mop Hndle   2022       3      1.0       7.3700
# 4079    Tiger Glucose FP   2022       5      7.0       6.9300
# 3215     Ponni Rice 20lb   2022       5     20.0       0.0000
# 3837    Soak&BoilToorDal   2022       5   1668.0       0.0000
# 4344  Veg.Dumpling 17.5L   2022       5    672.0       0.0000
#
# [4531 rows x 5 columns]

# %%
data9 = df[['months','years','ShortName','saleqty','saleamt']][(df['months'] >=3) & (df['months'] <=5) & (df['years'] == 2023)].groupby(['ShortName','years','months'], as_index=False).sum().sort_values('saleamt',ascending=False)
data9
# Out:
#                ShortName  years  months  saleqty      saleamt
# 600     Chakki Atta 20Lb   2023       3  44730.0  686005.3500
# 601     Chakki Atta 20Lb   2023       4  40602.0  578814.8400
# 602     Chakki Atta 20Lb   2023       5  35074.0  492942.7600
# 4159  Tandoori Naan 16PC   2023       3  55184.0  293597.3516
# 4160  Tandoori Naan 16PC   2023       4  44824.0  220041.3316
# ...                  ...    ...     ...      ...          ...
# 2133  Karahi Gosht 3.5oz   2023       4     10.0      13.2200
# 1062  CyanPrintT-Shirt S   2023       3      1.0      10.4500
# 1059  CyanPrintT-Shirt L   2023       5      1.0      10.4500
# 4332  TreatStrawbr4.23Oz   2023       5     10.0       4.0000
# 1341    ExLGrainBasmati7   2023       3    150.0       0.0000
#
# [4704 rows x 5 columns]

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2022 Sales in Spring',pad=15)
sns.barplot(x='ShortName', y='saleamt',data=data8[:20], color="b",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data8[:20], color="lightblue", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2023 Sales in Spring')
sns.barplot(x='ShortName', y='saleamt',data=data9[:20], color="darkorange",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data9[:20], color="green", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
data10 = df[['months','years','ShortName','saleqty','saleamt']][(df['months'] >=6) & (df['months'] <=8) & (df['years'] == 2022)].groupby(['ShortName','years','months'], as_index=False).sum().sort_values('saleamt',ascending=False)
data10
# Out:
#                ShortName  years  months  saleqty      saleamt
# 1655      Gold Atta 20lb   2022       7  35210.0  523092.9400
# 631     Chakki Atta 20Lb   2022       7  35836.0  392000.2054
# 4140  Tandoori Naan 16PC   2022       8  52304.0  280831.2222
# 630     Chakki Atta 20Lb   2022       6  24344.0  254427.2000
# 2052   Jumbo Samosa 15pc   2022       8  31828.0  253581.5094
# ...                  ...    ...     ...      ...          ...
# 1910   I.K Paneer Kulcha   2022       8     18.0       0.0000
# 1911  IK MiniOnionPakora   2022       8     36.0       0.0000
# 1912  IK Samosa Patti PT   2022       8     72.0       0.0000
# 4340  TurmericF.Wash0.5m   2022       8     48.0       0.0000
# 3744  Saff.MintF.Wash0.5   2022       8     72.0       0.0000
#
# [4681 rows x 5 columns]

# %%
data11 = df[['months','years','ShortName','saleqty','saleamt']][(df['months'] >=6) & (df['months'] <=8) & (df['years'] == 2023)].groupby(['ShortName','years','months'], as_index=False).sum().sort_values('saleamt',ascending=False)
data11
# Out:
#                ShortName  years  months  saleqty      saleamt
# 596     Chakki Atta 20Lb   2023       7  54418.0  741849.1100
# 597     Chakki Atta 20Lb   2023       8  44700.0  608220.1000
# 595     Chakki Atta 20Lb   2023       6  39478.0  541643.3900
# 4178  Tandoori Naan 16PC   2023       6  56216.0  287152.6992
# 4180  Tandoori Naan 16PC   2023       8  51960.0  264036.6900
# ...                  ...    ...     ...      ...          ...
# 1327    ExLGrainBasmati7   2023       8     60.0       0.0000
# 4159   TUB Falooda Kulfi   2023       6     19.0       0.0000
# 1326    ExLGrainBasmati7   2023       7    300.0       0.0000
# 1325    ExLGrainBasmati7   2023       6   1230.0       0.0000
# 1217   Display Floor Box   2023       6     10.0       0.0000
#
# [4727 rows x 5 columns]

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2022 Sales in Summer',pad=15)
sns.barplot(x='ShortName', y='saleamt',data=data10[:20], color="gold",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data10[:20], color="green", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2023 Sales in Summer')
sns.barplot(x='ShortName', y='saleamt',data=data11[:20], color="cyan",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data11[:20], color="yellow", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
data12 = df[['months','years','ShortName','saleqty','saleamt']][(df['months'] >=9) & (df['months'] <=11) & (df['years'] == 2022)].groupby(['ShortName','years','months'], as_index=False).sum().sort_values('saleamt',ascending=False)
data12
# Out:
#                ShortName  years  months  saleqty      saleamt
# 622     Chakki Atta 20Lb   2022       9  22282.0  292295.5100
# 4226  Tandoori Naan 16PC   2022       9  47888.0  257116.7952
# 2096   Jumbo Samosa 15pc   2022       9  30924.0  245849.1454
# 4228  Tandoori Naan 16PC   2022      11  43848.0  235802.0818
# 4227  Tandoori Naan 16PC   2022      10  42048.0  224701.0262
# ...                  ...    ...     ...      ...          ...
# 2312     Kraft Paper Bag   2022      11      1.0      14.4000
# 1948  IKB.PizzaWithSauce   2022      10      4.0      12.6800
# 2673  MatkiDiva Kodia10p   2022      11     20.0      11.3800
# 4165  SugarCoat.Fenn.7oz   2022      10     20.0      11.0900
# 4667       Wet Mop Hndle   2022       9      1.0       8.3700
#
# [4781 rows x 5 columns]

# %%
data13 = df[['months','years','ShortName','saleqty','saleamt']][(df['months'] >=9) & (df['months'] <=11) & (df['years'] == 2023)].groupby(['ShortName','years','months'], as_index=False).sum().sort_values('saleamt',ascending=False)
data13
# Out:
#                ShortName  years  months  saleqty      saleamt
# 617   Chakki Atta 20+2Lb   2023      10  48732.0  620649.1600
# 619     Chakki Atta 20Lb   2023       9  31060.0  425213.8700
# 618   Chakki Atta 20+2Lb   2023      11  27178.0  349687.8800
# 4454   WaghBakri Tea 2LB   2023      10  41004.0  270458.3200
# 4045  Tandoori Naan 16PC   2023       9  49536.0  256027.2118
# ...                  ...    ...     ...      ...          ...
# 453         Bottle Water   2023      11     24.0      12.2300
# 4210  Treat Pineapple3.5   2023      11     24.0      10.8500
# 4136     Time Pass 1.4Oz   2023       9     40.0      10.8300
# 2250     Lg SS Scrubbers   2023      11     12.0       9.4800
# 4460       Wet Mop Hndle   2023      10      1.0       8.0400
#
# [4577 rows x 5 columns]

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2022 Sales in Autumn',pad=15)
sns.barplot(x='ShortName', y='saleamt',data=data12[:20], color="b",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data12[:20], color="lightblue", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2023 Sales in Autumn')
sns.barplot(x='ShortName', y='saleamt',data=data13[:20], color="darkorange",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data13[:20], color="green", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
data14 = df[['months','years','ShortName','saleqty','saleamt']][((df['months'] <3) | (df['months'] >11)) & (df['years'] == 2022)].groupby(['ShortName','years','months'], as_index=False).sum().sort_values('saleamt',ascending=False)
data14
# Out:
#                ShortName  years  months  saleqty      saleamt
# 576     Chakki Atta 20Lb   2022      12  21774.0  336779.9500
# 3944  Tandoori Naan 16PC   2022      12  54688.0  290431.2596
# 3942  Tandoori Naan 16PC   2022       1  45016.0  231890.5181
# 1923   Jumbo Samosa 15pc   2022      12  26892.0  210195.3452
# 3943  Tandoori Naan 16PC   2022       2  38616.0  207405.4324
# ...                  ...    ...     ...      ...          ...
# 1006  CyanPrintT-Shirt L   2022      12      1.0      10.4500
# 1008  CyanPrintT-ShirtXL   2022      12      1.0      10.4500
# 1519  GloveBLKforDishwas   2022       2      1.0       8.9100
# 947   Cuc.Aloe.F.Wash5.0   2022       2      6.0       0.0000
# 1213  Eco Craft Sandwich   2022      12   4000.0       0.0000
#
# [4469 rows x 5 columns]

# %%
data15 = df[['months','years','ShortName','saleqty','saleamt']][((df['months'] <3) | (df['months'] >11)) & (df['years'] == 2023)].groupby(['ShortName','years','months'], as_index=False).sum().sort_values('saleamt',ascending=False)
data15.head(8)
# Out:
#                ShortName  years  months  saleqty       saleamt
# 534     Chakki Atta 20Lb   2023       1  87928.0  1.359762e+06
# 535     Chakki Atta 20Lb   2023       2  42584.0  6.613277e+05
# 533   Chakki Atta 20+2Lb   2023      12  22818.0  3.002816e+05
# 3743  Tandoori Naan 16PC   2023       1  48672.0  2.608644e+05
# 3744  Tandoori Naan 16PC   2023       2  38960.0  2.088609e+05
# 1820   Jumbo Samosa 15pc   2023       1  22176.0  1.728188e+05
# 3745  Tandoori Naan 16PC   2023      12  33368.0  1.655479e+05
# 1821   Jumbo Samosa 15pc   2023       2  20988.0  1.616140e+05

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2022 Sales in Winter',pad=15)
sns.barplot(x='ShortName', y='saleamt',data=data14[:20], color="green",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data14[:20], color="gold", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
f, ax = plt.subplots(figsize=(36, 15))
plt.title('2023 Sales in Winter')
sns.barplot(x='ShortName', y='saleamt',data=data15[:20], color="maroon",label="Sale Amount")
sns.barplot(x='ShortName', y='saleqty',data=data15[:20], color="chocolate", label="Sale Quantity")
ax.legend()
ax.set(ylabel="Sale Quantity and Amount", xlabel="Products Sale")
plt.show()

# %%
dicto1 = [data8[['saleamt','saleqty']].mean().values,data10[['saleamt','saleqty']].mean().values,data12[['saleamt','saleqty']].mean().values,data14[['saleamt','saleqty']].mean().values]
dicto1
# Out:
# [array([5358.96916997, 2882.88148312]),
#  array([5838.8100585 , 2494.71031831]),
#  array([5562.6389325 , 2449.64620372]),
#  array([5162.31148223, 2321.81886328])]

# %%
import numpy as np

# %%
df2 = pd.DataFrame(dicto1, columns=['saleamt','saleqty'])
df2['years'] = data8['years']
df2['season'] = np.array(['Spring','Summer','Autumn','Winter'])
df2
# Out:
#        saleamt      saleqty  years  season
# 0  5358.969170  2882.881483   2022  Spring
# 1  5838.810058  2494.710318   2022  Summer
# 2  5562.638932  2449.646204   2022  Autumn
# 3  5162.311482  2321.818863   2022  Winter

# %%
dicto2 = [data9[['saleamt','saleqty']].mean().values,data11[['saleamt','saleqty']].mean().values,data13[['saleamt','saleqty']].mean().values,data15[['saleamt','saleqty']].mean().values]
dicto2
# Out:
# [array([5708.80548026, 2370.8892432 ]),
#  array([5843.46008052, 2385.81573937]),
#  array([4974.44105445, 2071.70941665]),
#  array([5163.93781801, 2117.86571563])]

# %%
df3 = pd.DataFrame(dicto2, columns=['saleamt','saleqty'])
df3['years'] = data9['years']
df3['season'] = np.array(['Spring','Summer','Autumn','Winter'])
df3
# Out:
#        saleamt      saleqty  years  season
# 0  5708.805480  2370.889243   2023  Spring
# 1  5843.460081  2385.815739   2023  Summer
# 2  4974.441054  2071.709417   2023  Autumn
# 3  5163.937818  2117.865716   2023  Winter

# %%
f, ax = plt.subplots()
plt.title('Sale Comparision of 2022-2023')
ax.plot(df2['season'],df2['saleamt'],linestyle='dotted', linewidth=2.0, label='2022')
ax.plot(df3['season'],df3['saleamt'],linestyle='dashed', linewidth=2.0, label='2023')
plt.legend()
plt.xlabel('Season')
plt.ylabel('Total Sales Amount')
plt.show()

# %%
f, ax = plt.subplots()
plt.title('Sale Comparision of 2022-2023')
ax.plot(df2['season'],df2['saleqty'],  linestyle='dotted', linewidth=2.0, label='2022')
ax.plot(df3['season'],df3['saleqty'], linestyle='dashed', linewidth=2.0, label='2023')
plt.legend()
plt.xlabel('Season')
plt.ylabel('Total Sales Quantity')
plt.show()

# %%
data16 =  df[['ShortName','saleqty']][(df['months'] >=3) & (df['months'] <=5) & (df['years'] == 2022)].groupby(['ShortName'], as_index=False).sum()
data16
# Out:
#                ShortName  saleqty
# 0       1 Comt.Ovel Bowl    488.0
# 1     1-C Pet Clear  Lid    168.0
# 2      10 OZ. Paper Bowl     20.0
# 3     16 OZ Cld Drik.Cup     20.0
# 4     16 OZ Plastic Cups    120.0
# ...                  ...      ...
# 1640    Yello Vatana 2lb   2520.0
# 1641   Yellow Vatana 4lb   2280.0
# 1642  Young CoconutWater  12180.0
# 1643  Zeera Cookies12.3o    516.0
# 1644  lid4oz Portion cup    320.0
#
# [1645 rows x 2 columns]

# %%
data17 = df[['ShortName','saleqty']][(df['months'] >=3) & (df['months'] <=5) & (df['years'] == 2023)].groupby(['ShortName'], as_index=False).sum()
data17
# Out:
#                ShortName  saleqty
# 0     1 1/2Oz PortionCup  15000.0
# 1       1 Comt.Ovel Bowl    488.0
# 2     1-C Pet Clear  Lid    132.0
# 3     1/2 FiberTray Lids    200.0
# 4     16 OZ Cld Drik.Cup     20.0
# ...                  ...      ...
# 1648    Yello Vatana 2lb   2000.0
# 1649   Yellow Vatana 4lb   1290.0
# 1650  Young CoconutWater   4920.0
# 1651  Zeera Cookies12.3o    480.0
# 1652  lid4oz Portion cup    320.0
#
# [1653 rows x 2 columns]

# %%
df4 = data16.merge(data17, how='inner', on='ShortName')
df4['saleqty_x'] = df4['saleqty_x'].astype(int)
df4['saleqty_y'] = df4['saleqty_y'].astype(int)
df4
# Out:
#                ShortName  saleqty_x  saleqty_y
# 0       1 Comt.Ovel Bowl        488        488
# 1     1-C Pet Clear  Lid        168        132
# 2     16 OZ Cld Drik.Cup         20         20
# 3     16 OZ Plastic Cups        120         20
# 4       16oz Plastic Lid         40         10
# ...                  ...        ...        ...
# 1446    Yello Vatana 2lb       2520       2000
# 1447   Yellow Vatana 4lb       2280       1290
# 1448  Young CoconutWater      12180       4920
# 1449  Zeera Cookies12.3o        516        480
# 1450  lid4oz Portion cup        320        320
#
# [1451 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(30,15))
df4.plot(kind='scatter', x='saleqty_x', y='saleqty_y', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
f, ax = plt.subplots(figsize=(80,30))
plt.title('Sale Comparision of 2022-2023')
ax.plot(df4['ShortName'][:50],df4['saleqty_x'][:50], linewidth=3.0, label='2022')
ax.plot(df4['ShortName'][:50],df4['saleqty_y'][:50], linestyle='dashed', linewidth=4.0, label='2023',color='orange')
plt.legend()
plt.xlabel('ShortName')
plt.ylabel('Total Sales Quantity')
# plt.yscale('log')
plt.show()

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
model = LinearRegression()

# %%
df
# Out:
#         item_id item_code           ShortName  years  months     saleamt  \
# 0             1        11       Hot Mix 12oz.   2022       1  21227.2526
# 4             5        25     Bhel Mix 12 oz.   2022       1   2726.5795
# 8             9        34    Tm date chny10oz   2022       1  10201.6878
# 9            10        36      TamDat Sce18oz   2022       1   8898.9370
# 11           11        41      Boondi 14.1oz.   2022       1   2406.6878
# ...         ...       ...                 ...    ...     ...         ...
# 109164     6025      XM17  XM SabudanaKhichdi   2023      12     67.9400
# 109166     6150      XM19  XM Dal Dhokli3.2Oz   2023      12     33.6500
# 109170     5106      ZD12    Chick Peas 29oz.   2023      12    314.2000
# 109174     5110      ZD16   KraftCheddarChs 7   2023      12    126.1600
# 109179     5977      ZD22  Pitted Dates 24 oz   2023      12    356.0800
#
#         saleqty  cancelamt  cancelqty
# 0        7080.0     541.71      180.0
# ...

# %%
X = df.iloc[:,4:5].values
print(X)
# Out:
# [[ 1]
#  [ 1]
#  [ 1]
#  ...
#  [12]
#  [12]
#  [12]]

# %%
y = df.iloc[:,6].values
y
# Out:
# array([7080.,  996., 5676., ...,  120.,   36.,   72.])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=42,test_size=0.3)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([2145.69918662, 2034.22813749, 2089.96366205, ..., 2034.22813749,
#        2145.69918662, 2480.11233402])

# %%
y_test
# Out:
# array([  42., 1668.,   90., ...,  928.,  110.,  312.])

# %%
model.coef_
# Out:
# array([-55.73552457])

# %%
model.intercept_
# Out:
# 2703.054432283204

# %%
plt.scatter(X_test, y_test, color="black")
plt.plot(X_test, y_pred, color="blue", linewidth=3)

# %%
y = model.coef_*1 + model.intercept_
y
# Out:
# array([2647.31890772])
